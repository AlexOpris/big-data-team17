-- %%
-- Create a catalog (if it doesn't exist)
CREATE CATALOG IF NOT EXISTS methane;

-- Create a schema inside the catalog
CREATE SCHEMA IF NOT EXISTS methane.raw;

-- Create a volume in the schema
CREATE VOLUME IF NOT EXISTS methane.raw.emissions;
